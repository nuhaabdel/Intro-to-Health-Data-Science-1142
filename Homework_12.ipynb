# %% [markdown]
# **Create multiple linear regression model with WCC and CRP as predictors of Lipase.**

# %%
import statsmodels.api as sm
model = sm.OLS (y,x).fit()
print(model.summary())

# %% [markdown]
# **Comment on the F statistic.**

# %% [markdown]
# the F-stats is (p>0.001), showing that WCC and CRP together significantly predict Lipase

# %% [markdown]
# **Comment on the individual coefficients and their p values.**

# %% [markdown]
# CRP is strong and statistically important predictor of Lipase. WCC is less important because of multicollinearity with CRP, since CRP is derived from WCC.

# %% [markdown]
# **Comment on the  R^2 value**

# %% [markdown]
# The R^2 value is high, showing that the model explains a large protion of the variability in Lipase.
